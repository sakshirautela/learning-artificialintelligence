# %%
import numpy as np 
import matplotlib.pyplot as plt 
import cv2 as c

# %%
img=plt.imread('dummy.jpeg')
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
dummy=np.zeros((100,100,3),dtype=np.uint8)
image=c.imwrite('dummy.jpeg',dummy)
plt.imshow(c.cvtColor(dummy,c.COLOR_BGR2RGB))
plt.show()
