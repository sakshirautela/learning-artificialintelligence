# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import statistics

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
np.mean(df['total_bill'])
# Out:
# 19.78594262295082

# %%
np.median(df['total_bill'])
# Out:
# 17.795

# %%
statistics.mode(df['total_bill'])
# Out:
# 13.42

# %%
sns.boxplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.histplot(df['total_bill'],kde=True) #not a normal distribution
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df1=sns.load_dataset('iris')
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(df1['sepal_width'],kde=True) #normal distribution
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(df1['sepal_length'],kde=True) #not a normal distribution
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df1['petal_length'],kde=True) #not a normal distribution
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(df1['petal_width'],kde=True) #not a normal distribution
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.countplot(df1['species'])
# Out:
# <Axes: xlabel='count', ylabel='species'>

# %% [markdown]
# # how to detect outliers

# %%
dataset=[11,10,12,14,12,15,14,13,15,102,12,14,17,19,107,10,13,12,14,12,108,12,11,14,13,15,10,15,12,10,14,13,15,10]

sns.histplot(dataset)
# Out:
# <Axes: ylabel='Count'>

# %%
outliers=[] # holding all the outliers
def detect_outliers(data):
    threshold=3 #3rd std
    mean=np.mean(data)
    std=np.std(data)
    for i in data:
        z_score=(i-mean)/std
        if z_score>threshold:
            outliers.append(i)
detect_outliers(dataset)
outliers
# Out:
# [102, 107, 108]

# %% [markdown]
# # IQR
# how to find IQR
#
# Step 1: sort the list
#
# Step 2 get q3 and q1
#
# step 3 IQR(Q3-Q1)
#
# step 4 lower fence= q1-1.5*IQR
#         upper fence= q3+1.5*IQR

# %%
dataset.sort()
q3=(25/100)*(len(dataset)+1)
